# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv('/content/weather_hourly_darksky.csv')
df.head()
# Out:
#    visibility  windBearing  ...  humidity        summary
# 0        5.97          104  ...      0.91  Partly Cloudy
# 1        4.88           99  ...      0.94  Partly Cloudy
# 2        3.70           98  ...      0.96  Partly Cloudy
# 3        3.12           99  ...      0.96          Foggy
# 4        1.85          111  ...      1.00          Foggy
#
# [5 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# visibility              0
# windBearing             0
# temperature             0
# time                    0
# dewPoint                0
# pressure               13
# apparentTemperature     0
# windSpeed               0
# precipType              0
# icon                    0
# humidity                0
# summary                 0
# dtype: int64

# %%
df['pressure'] = df['pressure'].fillna(df['pressure'].mean())

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)

# %%
plt.figure(figsize=(20, 10))
p = sns.heatmap(df.corr(), annot=True)

# %%
df['Date'] = pd.to_datetime(df['time'])
df['Year'] = df['Date'].dt.year

# %%
p = sns.lineplot(x="Year", y="visibility", data=df)
_ = plt.ylabel("visibility")

# %%
p = sns.lineplot(x="Year", y="windBearing", data=df)
_ = plt.ylabel("windBearing")

# %%
p = sns.lineplot(x="Year", y="temperature", data=df)
_ = plt.ylabel("temperature")

# %%
p = sns.lineplot(x="Year", y="dewPoint", data=df)

# %%
p = sns.lineplot(x="Year", y="pressure", data=df)
_ = plt.ylabel("pressure")

# %%
p = sns.lineplot(x="Year", y="windSpeed", data=df)
_ = plt.ylabel("windspeed")

# %%
plt.figure(figsize=(20, 10))
p = sns.countplot(x='summary', data=df)
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
df.head()
# Out:
#    visibility  windBearing  ...                Date  Year
# 0        5.97          104  ... 2011-11-11 00:00:00  2011
# 1        4.88           99  ... 2011-11-11 01:00:00  2011
# 2        3.70           98  ... 2011-11-11 02:00:00  2011
# 3        3.12           99  ... 2011-11-11 03:00:00  2011
# 4        1.85          111  ... 2011-11-11 04:00:00  2011
#
# [5 rows x 14 columns]

# %%
df = df.drop(['summary','Date','time'],axis=1)

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.head()
# Out:
#    visibility  windBearing  ...  icon_partly-cloudy-night  icon_wind
# 0        5.97          104  ...                         1          0
# 1        4.88           99  ...                         1          0
# 2        3.70           98  ...                         1          0
# 3        3.12           99  ...                         0          0
# 4        1.85          111  ...                         0          0
#
# [5 rows x 16 columns]

# %%
X = df.drop(['temperature'],axis=1)
X
# Out:
#        visibility  windBearing  ...  icon_partly-cloudy-night  icon_wind
# 0            5.97          104  ...                         1          0
# 1            4.88           99  ...                         1          0
# 2            3.70           98  ...                         1          0
# 3            3.12           99  ...                         0          0
# 4            1.85          111  ...                         0          0
# ...           ...          ...  ...                       ...        ...
# 21160       12.68          247  ...                         1          0
# 21161       13.78          249  ...                         0          0
# 21162       14.31          248  ...                         0          0
# 21163       14.31          248  ...                         0          0
# 21164       14.31          246  ...                         0          0
#
# [21165 rows x 15 columns]

# %%
y = df['temperature']
y
# Out:
# 0        10.24
# 1         9.76
# 2         9.46
# 3         9.23
# 4         9.26
#          ...
# 21160     7.39
# 21161     6.56
# 21162     6.47
# 21163     5.96
# 21164     5.38
# Name: temperature, Length: 21165, dtype: float64

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

X_scaled  = preprocessing.scale(X) 
poly = PolynomialFeatures(5) 

X_final = poly.fit_transform(X_scaled)

X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)

# %%
from sklearn import linear_model

regr = linear_model.Ridge(alpha = 0.5) 
regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)
y_pred
# Out:
# array([11.28564587,  2.42252414, 17.09803943, ...,  9.09859319,
#         4.25042083,  3.88916429])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Display Model Intercept
print("Intercept: ", regr.intercept_)

# Display Model coefficients
print('Coefficients: \n', len(regr.coef_ ))


print('Mean squared error: %.3f' % mean_squared_error(y_test,  y_pred))


# r2_score (Coefficient of determination) is a great evaluation metric - read more below
print('Coefficient of determination: %.3f' % r2_score(y_test, y_pred))
# Out:
# Intercept:  10.15786498570553
# Coefficients:
#  15504
# Mean squared error: 0.007
# Coefficient of determination: 1.000

# %%
import pickle
with open('Weather_Temp_prediction','wb') as f:
    pickle.dump(regr,f)

# %%
# Input the attribute of X table  
weatherObs = [[5.97, 104, 8.86, 1016.76, 10.24, 2.77,0.91,2011,0,0,0,0,0,1,0]]

# Apply the same preprocessing steps
weatherObs_scaled = preprocessing.scale(weatherObs) 
weatherObs_final = poly.fit_transform(weatherObs_scaled)

# Use our model to make a prediction for Humidity
y_pred = regr.predict(weatherObs_final)
y_pred
# Out:
# array([10.15786499])
